# %% [markdown]
# # Heights
#
# Let's calculate measures of center and spread using the height data from GEOF210.

# %%
height = [173, 169, 170, 164, 180, 175, 174, 164, 175, 170, 167, 172, 178, 169, 165, 165, 170, 165, 180, 170, 171, 193, 150, 164, 155, 158, 164, 182, 175, 175, 180, 178, 180, 168, 178, 186, 186, 192, 185, 167, 156]
gender = ['m', 'f', 'f', 'f', 'm', 'm', 'm', 'f', 'f', 'f', 'm', 'f', 'm', 'f', 'f', 'f', 'f', 'f', 'm', 'f', 'f', 'm', 'm', 'f', 'f', 'f', 'f', 'm', 'm', 'm', 'm', 'm', 'm', 'f', 'f', 'm', 'm', 'm', 'm', 'f', 'f']

# %% [markdown]
# ## Center
#
# Let's calculate measures of center using the height data from GEOF210.
#
# Mean: $ \hspace{1cm} \bar{x} = \frac{1}{N} \sum\limits_{i = 1}^{N} x_{i} $

# %%
# Write your code here - use the formula for calculating the mean

# %% [markdown]
# Or simply use Python's function for calculating means.

# %%
import statistics             # We need to import the statistics module in order to use the mean function
# Write your code here

# %% [markdown]
# The median is the middle value in a sorted set of values.

# %%
# Write your code here

# %% [markdown]
# The mode is the most frequently occurring number

# %%
# Write your code here

# %% [markdown]
# ## Spread
#
# Let's calculate measures of spread.
#
# Standard deviation: $ \hspace{1cm} s = \sqrt(\frac{1}{(N - 1)} \sum\limits_{i = 1}^{N} (x_{i} - \bar{x})^2) $

# %%
import math                                # we also need the math module
# Write your code here - try to calculate the standard deviation using the formula above

# %% [markdown]
# Or use Python's function for calculating standard deviation

# %%
# Write your code here

# %% [markdown]
# The range is the absolute difference between endpoint values

# %%
# Write your code here
# if you obtain a range or other measures of spread that are unrealistically large, check your data for outliers or errors
#   - perhaps the data should have been plotted first...?

# %% [markdown]
# Or use the built-in range function

# %%
import numpy as np                         # it seems that we need numpy to get the range function
# Write your code here

# %% [markdown]
# ## Plot
#
# Use Matplotlib to make a histogram of the data.

# %%
import matplotlib.pyplot as plt
# Write your code here

# %% [markdown]
# If you have time, try to distinguish heights by gender

# %%
# Write your code here
